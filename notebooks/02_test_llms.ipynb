# %% [markdown]
# # Test LLM providers
#
# Sanity check: call the configured LLM through `ragger.llm.get_chat_fn` and confirm a response comes back.

# %%
import sys
sys.path.insert(0, "../src")

from core.config import load_config
from ragger.llm import get_chat_fn

config = load_config()
config.llm_provider

# %%
chat = get_chat_fn(config)
response = chat("You are a concise assistant.", "Reply with exactly one short sentence confirming you received this message.")
print(response)
